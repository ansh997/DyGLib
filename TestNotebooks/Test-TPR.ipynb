# %%
# scratch_location = r'/scratch/hmnshpl'
import getpass
import pandas as pd
import numpy as np
import networkx as nx

dataset_name = 'wikipedia'
scratch_location = rf'/scratch/{getpass.getuser()}'

# %%
from copy import deepcopy
import os
import sys

# %%
# Load data and train val test split
graph_df = pd.read_csv('{}/processed_data/{}/ml_{}.csv'.format(scratch_location,
                                                            dataset_name,
                                                            dataset_name)
                    )
edge_raw_features = np.load('{}/processed_data/{}/ml_{}.npy'.format(scratch_location,
                                                                    dataset_name,
                                                                    dataset_name)
                            )
node_raw_features = np.load('{}/processed_data/{}/ml_{}_node.npy'.format(scratch_location,
                                                                        dataset_name,
                                                                        dataset_name)
                            )

# %%
# Extract nodes, edges, and timestamps
edges = graph_df[['u', 'i', 'ts']].values

# %%
# get the timestamp of validate and test set
val_ratio = test_ratio = 0.495
val_time, test_time = list(np.quantile(graph_df.ts, [(1 - val_ratio - test_ratio), (1 - test_ratio)]))

# %%
# Split data into train, val, test (assuming you have timestamps for this)
train_edges = edges[edges[:, 2] < val_time]
val_edges = edges[(edges[:, 2] >= val_time) & (edges[:, 2] < test_time)]
test_edges = edges[edges[:, 2] >= test_time]

# %%
# Create a bipartite temporal graph
G = nx.Graph()
for edge in train_edges:
    source, target, timestamp = edge
    G.add_edge(source, target, timestamp=timestamp)

# %%
# Initialize PageRank scores
page_rank_scores = {node: 1.0 / G.number_of_nodes() for node in G.nodes()}
init_page_rank_scores = deepcopy(page_rank_scores)

# %%
# Parameters for Temporal PageRank
alpha = 0.85  # Damping factor
max_iter = 100
tol = 1e-6

def temporal_page_rank(G, alpha=0.85, max_iter=100, tol=1e-6):
    nodes = G.nodes()
    num_nodes = G.number_of_nodes()
    
    # Initialize PageRank scores
    pr = {node: 1.0 / num_nodes for node in nodes}
    temp_pr = pr.copy()

    for _ in range(max_iter):
        change = 0
        for node in nodes:
            rank_sum = sum(pr[neighbor] / len(G[neighbor]) for neighbor in G.neighbors(node) if 'timestamp' in G[node][neighbor])
            temp_pr[node] = (1 - alpha) / num_nodes + alpha * rank_sum
        
        # Calculate change for convergence check
        change = sum(abs(temp_pr[node] - pr[node]) for node in nodes)
        
        if change < tol:
            break
        
        pr = temp_pr.copy()

    return pr

# %%
# Calculate Temporal PageRank
page_rank_scores = temporal_page_rank(G, alpha=0.85, max_iter=100, tol=1e-6)

# Output the PageRank scores
# print(page_rank_scores)

# %%
# Sort nodes by PageRank scores
sorted_nodes = sorted(page_rank_scores.items(), key=lambda item: item[1], reverse=True)

# Calculate the top 30% of nodes
top_30_percent_count = int(len(sorted_nodes) * 0.30)
top_30_percent_nodes = sorted_nodes[:top_30_percent_count]

# %%
len(top_30_percent_nodes), len(page_rank_scores)

# %%
100* (2242/7475)

# %%
# Output the top 30% of nodes and their PageRank scores
for node, score in top_30_percent_nodes:
    print(f'Node: {node:.0f}, PageRank Score: {score:.2e}, initial page_rank: {init_page_rank_scores[node]:.2e}')

# %%
# assert 0==1

# %%
# Set the working directory to the project root
project_root = os.path.abspath(os.path.join(os.path.dirname('__file__'), '..'))
sys.path.append(project_root)

# %%
# os.getcwd()
project_root
# Out:
# '/home2/hmnshpl/projects/DyGLib'

# %%
# from TPR.temporal_page_rank import TemporalPageRankComputer, TemporalPageRankParams

# %%
from TPR import temporal_pagerank

# %%
# Extract nodes, edges, and timestamps
edges = graph_df[['u', 'i', 'ts']].values
nodes = np.unique(edges[:, :2])  # Get unique nodes from edges

# %%
# Temporal PageRank Parameters
alpha = 0.85
beta = 0.1
params = temporal_pagerank.TemporalPageRankParams(alpha, beta)

# %%
# Initialize TemporalPageRankComputer
tpr_computer = temporal_pagerank.TemporalPageRankComputer(nodes, [params])

# %%
# Update PageRank Scores
for edge in edges:
    src, trg, timestamp = edge
    tpr_computer.update((src, trg))
    
# Function to convert results to dictionary
def get_pagerank_scores(tpr_computer):
    scores = {}
    for i, node in enumerate(tpr_computer.active_mass[:, 0]):
        scores[node] = tpr_computer.temp_pr[i, 1]
    return scores

# %%
# Get PageRank scores
page_rank_scores = get_pagerank_scores(tpr_computer)

# %%
page_rank_scores
# Out:
# {1.0: 0.15000000000000002,
#  2.0: 42.74999999999977,
#  3.0: 24.299999999999947,
#  4.0: 28.34999999999991,
#  5.0: 98.40000000000087,
#  6.0: 40.64999999999979,
#  7.0: 40.79999999999979,
#  8.0: 6.600000000000005,
#  9.0: 42.89999999999977,
#  10.0: 8.70000000000001,
#  11.0: 16.350000000000023,
#  12.0: 0.7500000000000001,
#  13.0: 41.84999999999978,
#  14.0: 22.649999999999963,
#  15.0: 7.350000000000007,
#  16.0: 1.35,
#  17.0: 16.200000000000024,
#  18.0: 88.20000000000049,
#  19.0: 25.04999999999994,
#  20.0: 0.30000000000000004,
#  21.0: 0.30000000000000004,
#  22.0: 0.6000000000000001,
#  23.0: 19.049999999999997,
#  24.0: 1.0500000000000003,
#  25.0: 16.65000000000002,
#  26.0: 10.500000000000014,
#  27.0: 1.5,
#  28.0: 44.24999999999976,
#  29.0: 1.2000000000000002,
#  30.0: 0.15000000000000002,
#  31.0: 0.6000000000000001,
#  32.0: 1.2000000000000002,
#  33.0: 0.15000000000000002,
#  34.0: 3.449999999999999,
#  35.0: 0.7500000000000001,
#  36.0: 1.0500000000000003,
#  37.0: 49.799999999999706,
#  38.0: 0.45000000000000007,
#  39.0: 0.15000000000000002,
#  40.0: 40.349999999999795,
#  41.0: 34.64999999999985,
#  42.0: 1.5,
#  43.0: 6.450000000000005,
#  44.0: 4.65,
#  45.0: 5.400000000000002,
#  46.0: 6.450000000000005,
#  47.0: 15.300000000000026,
#  48.0: 41.99999999999978,
#  49.0: 16.80000000000002,
#  50.0: 4.950000000000001,
#  51.0: 26.699999999999925,
#  52.0: 43.649999999999764,
#  53.0: 2.3999999999999995,
#  54.0: 2.849999999999999,
#  55.0: 2.999999999999999,
#  56.0: 0.6000000000000001,
#  57.0: 26.849999999999923,
#  58.0: 1.0500000000000003,
#  59.0: 15.000000000000025,
#  60.0: 13.350000000000021,
#  61.0: 2.999999999999999,
#  62.0: 3.449999999999999,
#  63.0: 3.299999999999999,
#  64.0: 19.049999999999997,
#  65.0: 1.5,
#  66.0: 4.5,
#  67.0: 44.549999999999756,
#  68.0: 5.850000000000003,
#  69.0: 102.45000000000103,
#  70.0: 1.7999999999999998,
#  71.0: 0.30000000000000004,
#  72.0: 3.8999999999999986,
#  73.0: 3.299999999999999,
#  74.0: 16.050000000000026,
#  75.0: 0.6000000000000001,
#  76.0: 7.050000000000006,
#  77.0: 83.10000000000029,
#  78.0: 0.6000000000000001,
#  79.0: 24.14999999999995,
#  80.0: 8.40000000000001,
#  81.0: 8.100000000000009,
#  82.0: 6.600000000000005,
#  83.0: 0.15000000000000002,
#  84.0: 2.0999999999999996,
#  85.0: 4.65,
#  86.0: 0.6000000000000001,
#  87.0: 20.399999999999984,
#  88.0: 17.55000000000001,
#  89.0: 41.99999999999978,
#  90.0: 2.5499999999999994,
#  91.0: 10.500000000000014,
#  92.0: 0.30000000000000004,
#  93.0: 1.5,
#  94.0: 12.90000000000002,
#  95.0: 28.649999999999906,
#  96.0: 13.20000000000002,
#  97.0: 14.550000000000024,
#  98.0: 0.15000000000000002,
#  99.0: 12.300000000000018,
#  100.0: 1.0500000000000003,
#  101.0: 0.9000000000000001,
#  102.0: 4.35,
#  103.0: 27.749999999999915,
#  104.0: 1.9499999999999997,
#  105.0: 16.50000000000002,
#  106.0: 0.7500000000000001,
#  107.0: 2.849999999999999,
#  108.0: 13.350000000000021,
#  109.0: 28.19999999999991,
#  110.0: 6.600000000000005,
#  111.0: 0.45000000000000007,
#  112.0: 1.5,
#  113.0: 3.7499999999999987,
#  114.0: 0.7500000000000001,
#  115.0: 4.800000000000001,
#  116.0: 0.45000000000000007,
#  117.0: 7.950000000000008,
#  118.0: 32.09999999999987,
#  119.0: 48.29999999999972,
#  120.0: 34.049999999999855,
#  121.0: 0.30000000000000004,
#  122.0: 0.15000000000000002,
#  123.0: 2.5499999999999994,
#  124.0: 4.199999999999999,
#  125.0: 194.4000000000045,
#  126.0: 7.200000000000006,
#  127.0: 0.30000000000000004,
#  128.0: 12.150000000000018,
#  129.0: 0.15000000000000002,
#  130.0: 1.2000000000000002,
#  131.0: 2.6999999999999993,
#  132.0: 1.2000000000000002,
#  133.0: 0.15000000000000002,
#  134.0: 0.15000000000000002,
#  135.0: 174.15000000000373,
#  136.0: 0.30000000000000004,
#  137.0: 6.300000000000004,
#  138.0: 0.45000000000000007,
#  139.0: 0.45000000000000007,
#  140.0: 1.2000000000000002,
#  141.0: 1.0500000000000003,
#  142.0: 0.30000000000000004,
#  143.0: 70.0499999999998,
#  144.0: 2.849999999999999,
#  145.0: 26.849999999999923,
#  146.0: 38.99999999999981,
#  147.0: 7.050000000000006,
#  148.0: 1.0500000000000003,
#  149.0: 4.800000000000001,
#  150.0: 0.45000000000000007,
#  151.0: 5.250000000000002,
#  152.0: 6.0000000000000036,
#  153.0: 0.30000000000000004,
#  154.0: 0.45000000000000007,
#  155.0: 0.6000000000000001,
#  156.0: 0.45000000000000007,
#  157.0: 10.050000000000013,
#  158.0: 15.750000000000027,
#  159.0: 0.30000000000000004,
#  160.0: 8.250000000000009,
#  161.0: 13.500000000000021,
#  162.0: 4.199999999999999,
#  163.0: 3.299999999999999,
#  164.0: 2.6999999999999993,
#  165.0: 42.14999999999978,
#  166.0: 8.55000000000001,
#  167.0: 0.15000000000000002,
#  168.0: 6.300000000000004,
#  169.0: 9.750000000000012,
#  170.0: 10.500000000000014,
#  171.0: 1.0500000000000003,
#  172.0: 11.850000000000017,
#  173.0: 1.9499999999999997,
#  174.0: 2.0999999999999996,
#  175.0: 12.300000000000018,
#  176.0: 6.750000000000005,
#  177.0: 0.15000000000000002,
#  178.0: 0.9000000000000001,
#  179.0: 57.74999999999963,
#  180.0: 45.749999999999744,
#  181.0: 1.7999999999999998,
#  182.0: 10.350000000000014,
#  183.0: 14.400000000000023,
#  184.0: 2.0999999999999996,
#  185.0: 6.900000000000006,
#  186.0: 7.950000000000008,
#  187.0: 0.15000000000000002,
#  188.0: 0.6000000000000001,
#  189.0: 1.35,
#  190.0: 2.999999999999999,
#  191.0: 6.150000000000004,
#  192.0: 0.7500000000000001,
#  193.0: 0.45000000000000007,
#  194.0: 14.700000000000024,
#  195.0: 2.2499999999999996,
#  196.0: 17.55000000000001,
#  197.0: 20.249999999999986,
#  198.0: 20.84999999999998,
#  199.0: 7.050000000000006,
#  200.0: 17.55000000000001,
#  201.0: 0.9000000000000001,
#  202.0: 0.15000000000000002,
#  203.0: 1.35,
#  204.0: 14.550000000000024,
#  205.0: 12.150000000000018,
#  206.0: 122.55000000000179,
#  207.0: 2.3999999999999995,
#  208.0: 1.0500000000000003,
#  209.0: 2.5499999999999994,
#  210.0: 1.7999999999999998,
#  211.0: 42.29999999999978,
#  212.0: 0.45000000000000007,
#  213.0: 13.350000000000021,
#  214.0: 1.9499999999999997,
#  215.0: 71.99999999999987,
#  216.0: 0.30000000000000004,
#  217.0: 10.200000000000014,
#  218.0: 0.9000000000000001,
#  219.0: 41.09999999999979,
#  220.0: 0.15000000000000002,
#  221.0: 34.049999999999855,
#  222.0: 90.90000000000059,
#  223.0: 2.849999999999999,
#  224.0: 4.65,
#  225.0: 37.79999999999982,
#  226.0: 18.000000000000007,
#  227.0: 25.349999999999937,
#  228.0: 12.150000000000018,
#  229.0: 1.7999999999999998,
#  230.0: 0.15000000000000002,
#  231.0: 22.79999999999996,
#  232.0: 5.400000000000002,
#  233.0: 25.649999999999935,
#  234.0: 126.45000000000194,
#  235.0: 1.35,
#  236.0: 1.2000000000000002,
#  237.0: 0.15000000000000002,
#  238.0: 23.84999999999995,
#  239.0: 2.0999999999999996,
#  240.0: 6.450000000000005,
#  241.0: 3.299999999999999,
#  242.0: 0.45000000000000007,
#  243.0: 8.40000000000001,
#  244.0: 0.45000000000000007,
#  245.0: 7.050000000000006,
#  246.0: 11.250000000000016,
#  247.0: 1.9499999999999997,
#  248.0: 2.2499999999999996,
#  249.0: 13.800000000000022,
#  250.0: 2.3999999999999995,
#  251.0: 47.849999999999724,
#  252.0: 0.15000000000000002,
#  253.0: 0.7500000000000001,
#  254.0: 1.0500000000000003,
#  255.0: 1.7999999999999998,
#  256.0: 18.150000000000006,
#  257.0: 13.05000000000002,
#  258.0: 22.199999999999967,
#  259.0: 0.30000000000000004,
#  260.0: 26.549999999999926,
#  261.0: 0.15000000000000002,
#  262.0: 3.149999999999999,
#  263.0: 0.30000000000000004,
#  264.0: 0.15000000000000002,
#  265.0: 16.50000000000002,
#  266.0: 0.15000000000000002,
#  267.0: 4.65,
#  268.0: 10.650000000000015,
#  269.0: 31.34999999999988,
#  270.0: 1.35,
#  271.0: 58.04999999999963,
#  272.0: 21.74999999999997,
#  273.0: 5.400000000000002,
#  274.0: 17.400000000000013,
#  275.0: 8.70000000000001,
#  276.0: 0.15000000000000002,
#  277.0: 19.94999999999999,
#  278.0: 18.150000000000006,
#  279.0: 6.600000000000005,
#  280.0: 0.15000000000000002,
#  281.0: 8.70000000000001,
#  282.0: 3.5999999999999988,
#  283.0: 0.15000000000000002,
#  284.0: 0.45000000000000007,
#  285.0: 5.100000000000001,
#  286.0: 114.30000000000148,
#  287.0: 7.6500000000000075,
#  288.0: 3.5999999999999988,
#  289.0: 2.849999999999999,
#  290.0: 10.950000000000015,
#  291.0: 29.2499999999999,
#  292.0: 9.00000000000001,
#  293.0: 17.250000000000014,
#  294.0: 0.30000000000000004,
#  295.0: 18.6,
#  296.0: 0.15000000000000002,
#  297.0: 4.65,
#  298.0: 0.7500000000000001,
#  299.0: 0.15000000000000002,
#  300.0: 0.15000000000000002,
#  301.0: 0.30000000000000004,
#  302.0: 3.299999999999999,
#  303.0: 0.30000000000000004,
#  304.0: 9.450000000000012,
#  305.0: 13.350000000000021,
#  306.0: 7.950000000000008,
#  307.0: 20.399999999999984,
#  308.0: 1.9499999999999997,
#  309.0: 40.349999999999795,
#  310.0: 7.050000000000006,
#  311.0: 2.999999999999999,
#  312.0: 27.29999999999992,
#  313.0: 4.049999999999999,
#  314.0: 0.7500000000000001,
#  315.0: 0.15000000000000002,
#  316.0: 2.5499999999999994,
#  317.0: 5.5500000000000025,
#  318.0: 1.5,
#  319.0: 16.350000000000023,
#  320.0: 26.549999999999926,
#  321.0: 0.30000000000000004,
#  322.0: 4.199999999999999,
#  323.0: 7.500000000000007,
#  324.0: 1.35,
#  325.0: 0.6000000000000001,
#  326.0: 12.60000000000002,
#  327.0: 0.15000000000000002,
#  328.0: 27.29999999999992,
#  329.0: 34.49999999999985,
#  330.0: 1.2000000000000002,
#  331.0: 1.35,
#  332.0: 7.500000000000007,
#  333.0: 0.6000000000000001,
#  334.0: 2.0999999999999996,
#  335.0: 20.399999999999984,
#  336.0: 55.94999999999965,
#  337.0: 0.9000000000000001,
#  338.0: 11.100000000000016,
#  339.0: 0.30000000000000004,
#  340.0: 10.800000000000015,
#  341.0: 23.699999999999953,
#  342.0: 0.45000000000000007,
#  343.0: 35.39999999999984,
#  344.0: 26.849999999999923,
#  345.0: 33.74999999999986,
#  346.0: 12.90000000000002,
#  347.0: 99.90000000000093,
#  348.0: 4.5,
#  349.0: 0.15000000000000002,
#  350.0: 3.5999999999999988,
#  351.0: 2.0999999999999996,
#  352.0: 0.7500000000000001,
#  353.0: 0.7500000000000001,
#  354.0: 18.6,
#  355.0: 0.7500000000000001,
#  356.0: 3.5999999999999988,
#  357.0: 2.849999999999999,
#  358.0: 0.30000000000000004,
#  359.0: 0.15000000000000002,
#  360.0: 6.300000000000004,
#  361.0: 0.30000000000000004,
#  362.0: 7.050000000000006,
#  363.0: 1.2000000000000002,
#  364.0: 0.15000000000000002,
#  365.0: 31.949999999999875,
#  366.0: 8.85000000000001,
#  367.0: 110.40000000000133,
#  368.0: 5.100000000000001,
#  369.0: 0.45000000000000007,
#  370.0: 0.45000000000000007,
#  371.0: 3.5999999999999988,
#  372.0: 18.300000000000004,
#  373.0: 1.2000000000000002,
#  374.0: 5.100000000000001,
#  375.0: 7.050000000000006,
#  376.0: 22.499999999999964,
#  377.0: 1.65,
#  378.0: 0.45000000000000007,
#  379.0: 4.65,
#  380.0: 81.15000000000022,
#  381.0: 0.15000000000000002,
#  382.0: 0.45000000000000007,
#  383.0: 33.29999999999986,
#  384.0: 3.149999999999999,
#  385.0: 6.0000000000000036,
#  386.0: 1.7999999999999998,
#  387.0: 0.6000000000000001,
#  388.0: 19.049999999999997,
#  389.0: 14.850000000000025,
#  390.0: 1.35,
#  391.0: 13.500000000000021,
#  392.0: 12.150000000000018,
#  393.0: 5.850000000000003,
#  394.0: 2.5499999999999994,
#  395.0: 0.15000000000000002,
#  396.0: 0.30000000000000004,
#  397.0: 0.15000000000000002,
#  398.0: 0.30000000000000004,
#  399.0: 2.6999999999999993,
#  400.0: 3.299999999999999,
#  401.0: 177.00000000000384,
#  402.0: 1.7999999999999998,
#  403.0: 13.800000000000022,
#  404.0: 11.250000000000016,
#  405.0: 23.09999999999996,
#  406.0: 0.6000000000000001,
#  407.0: 0.30000000000000004,
#  408.0: 0.30000000000000004,
#  409.0: 0.15000000000000002,
#  410.0: 0.15000000000000002,
#  411.0: 68.24999999999973,
#  412.0: 15.150000000000025,
#  413.0: 38.69999999999981,
#  414.0: 6.900000000000006,
#  415.0: 13.950000000000022,
#  416.0: 67.79999999999971,
#  417.0: 0.15000000000000002,
#  418.0: 64.04999999999957,
#  419.0: 2.849999999999999,
#  420.0: 0.9000000000000001,
#  421.0: 1.5,
#  422.0: 13.500000000000021,
#  423.0: 35.84999999999984,
#  424.0: 8.55000000000001,
#  425.0: 0.15000000000000002,
#  426.0: 4.65,
#  427.0: 2.999999999999999,
#  428.0: 0.45000000000000007,
#  429.0: 1.65,
#  430.0: 26.399999999999928,
#  431.0: 26.999999999999922,
#  432.0: 0.15000000000000002,
#  433.0: 0.9000000000000001,
#  434.0: 12.75000000000002,
#  435.0: 0.6000000000000001,
#  436.0: 0.7500000000000001,
#  437.0: 0.30000000000000004,
#  438.0: 15.150000000000025,
#  439.0: 0.7500000000000001,
#  440.0: 0.45000000000000007,
#  441.0: 12.150000000000018,
#  442.0: 6.0000000000000036,
#  443.0: 27.14999999999992,
#  444.0: 17.85000000000001,
#  445.0: 0.45000000000000007,
#  446.0: 12.450000000000019,
#  447.0: 0.15000000000000002,
#  448.0: 6.150000000000004,
#  449.0: 5.400000000000002,
#  450.0: 30.599999999999888,
#  451.0: 3.5999999999999988,
#  452.0: 4.049999999999999,
#  453.0: 0.15000000000000002,
#  454.0: 0.15000000000000002,
#  455.0: 0.15000000000000002,
#  456.0: 0.15000000000000002,
#  457.0: 2.2499999999999996,
#  458.0: 0.7500000000000001,
#  459.0: 0.6000000000000001,
#  460.0: 0.15000000000000002,
#  461.0: 2.999999999999999,
#  462.0: 5.5500000000000025,
#  463.0: 4.65,
#  464.0: 0.15000000000000002,
#  465.0: 8.40000000000001,
#  466.0: 50.849999999999696,
#  467.0: 1.65,
#  468.0: 9.300000000000011,
#  469.0: 0.15000000000000002,
#  470.0: 0.15000000000000002,
#  471.0: 0.30000000000000004,
#  472.0: 3.7499999999999987,
#  473.0: 5.400000000000002,
#  474.0: 0.15000000000000002,
#  475.0: 1.35,
#  476.0: 6.150000000000004,
#  477.0: 75.45,
#  478.0: 10.800000000000015,
#  479.0: 0.6000000000000001,
#  480.0: 1.2000000000000002,
#  481.0: 6.0000000000000036,
#  482.0: 8.55000000000001,
#  483.0: 24.449999999999946,
#  484.0: 24.449999999999946,
#  485.0: 12.450000000000019,
#  486.0: 13.20000000000002,
#  487.0: 16.950000000000017,
#  488.0: 23.84999999999995,
#  489.0: 10.500000000000014,
#  490.0: 1.7999999999999998,
#  491.0: 1.0500000000000003,
#  492.0: 0.30000000000000004,
#  493.0: 12.75000000000002,
#  494.0: 5.250000000000002,
#  495.0: 15.900000000000027,
#  496.0: 0.7500000000000001,
#  497.0: 6.900000000000006,
#  498.0: 3.7499999999999987,
#  499.0: 54.74999999999966,
#  500.0: 25.349999999999937,
#  501.0: 1.5,
#  502.0: 3.299999999999999,
#  503.0: 3.149999999999999,
#  504.0: 0.15000000000000002,
#  505.0: 26.849999999999923,
#  506.0: 0.15000000000000002,
#  507.0: 24.299999999999947,
#  508.0: 0.15000000000000002,
#  509.0: 2.5499999999999994,
#  510.0: 19.499999999999993,
#  511.0: 0.15000000000000002,
#  512.0: 0.6000000000000001,
#  513.0: 43.34999999999977,
#  514.0: 0.15000000000000002,
#  515.0: 0.7500000000000001,
#  516.0: 0.7500000000000001,
#  517.0: 4.199999999999999,
#  518.0: 8.100000000000009,
#  519.0: 6.150000000000004,
#  520.0: 0.15000000000000002,
#  521.0: 0.15000000000000002,
#  522.0: 20.249999999999986,
#  523.0: 0.30000000000000004,
#  524.0: 0.15000000000000002,
#  525.0: 27.749999999999915,
#  526.0: 20.69999999999998,
#  527.0: 14.850000000000025,
#  528.0: 0.9000000000000001,
#  529.0: 0.45000000000000007,
#  530.0: 0.30000000000000004,
#  531.0: 2.2499999999999996,
#  532.0: 4.049999999999999,
#  533.0: 9.00000000000001,
#  534.0: 7.350000000000007,
#  535.0: 6.750000000000005,
#  536.0: 72.5999999999999,
#  537.0: 1.7999999999999998,
#  538.0: 12.75000000000002,
#  539.0: 16.65000000000002,
#  540.0: 6.600000000000005,
#  541.0: 15.600000000000026,
#  542.0: 2.849999999999999,
#  543.0: 0.30000000000000004,
#  544.0: 1.65,
#  545.0: 0.45000000000000007,
#  546.0: 0.9000000000000001,
#  547.0: 0.7500000000000001,
#  548.0: 28.049999999999912,
#  549.0: 0.45000000000000007,
#  550.0: 2.999999999999999,
#  551.0: 0.15000000000000002,
#  552.0: 0.15000000000000002,
#  553.0: 14.700000000000024,
#  554.0: 0.15000000000000002,
#  555.0: 0.30000000000000004,
#  556.0: 2.3999999999999995,
#  557.0: 0.15000000000000002,
#  558.0: 25.499999999999936,
#  559.0: 0.7500000000000001,
#  560.0: 26.699999999999925,
#  561.0: 0.15000000000000002,
#  562.0: 2.2499999999999996,
#  563.0: 3.7499999999999987,
#  564.0: 1.0500000000000003,
#  565.0: 0.15000000000000002,
#  566.0: 0.15000000000000002,
#  567.0: 1.35,
#  568.0: 0.15000000000000002,
#  569.0: 0.30000000000000004,
#  570.0: 0.30000000000000004,
#  571.0: 15.000000000000025,
#  572.0: 6.150000000000004,
#  573.0: 0.7500000000000001,
#  574.0: 1.9499999999999997,
#  575.0: 2.3999999999999995,
#  576.0: 5.400000000000002,
#  577.0: 1.0500000000000003,
#  578.0: 4.5,
#  579.0: 18.300000000000004,
#  580.0: 4.950000000000001,
#  581.0: 0.15000000000000002,
#  582.0: 5.250000000000002,
#  583.0: 0.15000000000000002,
#  584.0: 0.30000000000000004,
#  585.0: 2.6999999999999993,
#  586.0: 0.15000000000000002,
#  587.0: 3.449999999999999,
#  588.0: 0.15000000000000002,
#  589.0: 2.5499999999999994,
#  590.0: 12.000000000000018,
#  591.0: 1.0500000000000003,
#  592.0: 10.200000000000014,
#  593.0: 0.7500000000000001,
#  594.0: 0.15000000000000002,
#  595.0: 0.15000000000000002,
#  596.0: 2.0999999999999996,
#  597.0: 6.150000000000004,
#  598.0: 0.30000000000000004,
#  599.0: 1.0500000000000003,
#  600.0: 0.15000000000000002,
#  601.0: 17.85000000000001,
#  602.0: 21.599999999999973,
#  603.0: 0.7500000000000001,
#  604.0: 2.0999999999999996,
#  605.0: 0.6000000000000001,
#  606.0: 0.15000000000000002,
#  607.0: 0.45000000000000007,
#  608.0: 0.45000000000000007,
#  609.0: 45.749999999999744,
#  610.0: 26.549999999999926,
#  611.0: 0.15000000000000002,
#  612.0: 19.79999999999999,
#  613.0: 1.9499999999999997,
#  614.0: 0.30000000000000004,
#  615.0: 0.9000000000000001,
#  616.0: 209.40000000000506,
#  617.0: 4.199999999999999,
#  618.0: 6.0000000000000036,
#  619.0: 0.45000000000000007,
#  620.0: 0.7500000000000001,
#  621.0: 1.35,
#  622.0: 1.0500000000000003,
#  623.0: 0.15000000000000002,
#  624.0: 66.74999999999967,
#  625.0: 5.700000000000003,
#  626.0: 5.100000000000001,
#  627.0: 0.30000000000000004,
#  628.0: 4.5,
#  629.0: 1.9499999999999997,
#  630.0: 0.45000000000000007,
#  631.0: 7.050000000000006,
#  632.0: 12.150000000000018,
#  633.0: 12.60000000000002,
#  634.0: 1.9499999999999997,
#  635.0: 0.7500000000000001,
#  636.0: 4.65,
#  637.0: 9.300000000000011,
#  638.0: 0.7500000000000001,
#  639.0: 0.45000000000000007,
#  640.0: 11.250000000000016,
#  641.0: 59.99999999999961,
#  642.0: 15.600000000000026,
#  643.0: 0.15000000000000002,
#  644.0: 0.15000000000000002,
#  645.0: 7.500000000000007,
#  646.0: 3.5999999999999988,
#  647.0: 12.450000000000019,
#  648.0: 0.45000000000000007,
#  649.0: 0.30000000000000004,
#  650.0: 2.2499999999999996,
#  651.0: 0.7500000000000001,
#  652.0: 5.400000000000002,
#  653.0: 0.45000000000000007,
#  654.0: 12.75000000000002,
#  655.0: 0.9000000000000001,
#  656.0: 8.85000000000001,
#  657.0: 10.950000000000015,
#  658.0: 0.45000000000000007,
#  659.0: 5.250000000000002,
#  660.0: 5.400000000000002,
#  661.0: 4.199999999999999,
#  662.0: 0.45000000000000007,
#  663.0: 2.2499999999999996,
#  664.0: 0.45000000000000007,
#  665.0: 2.0999999999999996,
#  666.0: 0.30000000000000004,
#  667.0: 7.950000000000008,
#  668.0: 1.2000000000000002,
#  669.0: 0.15000000000000002,
#  670.0: 0.15000000000000002,
#  671.0: 3.149999999999999,
#  672.0: 28.949999999999903,
#  673.0: 0.15000000000000002,
#  674.0: 0.45000000000000007,
#  675.0: 0.7500000000000001,
#  676.0: 18.6,
#  677.0: 0.45000000000000007,
#  678.0: 0.15000000000000002,
#  679.0: 24.14999999999995,
#  680.0: 0.30000000000000004,
#  681.0: 0.30000000000000004,
#  682.0: 8.250000000000009,
#  683.0: 0.6000000000000001,
#  684.0: 5.850000000000003,
#  685.0: 17.100000000000016,
#  686.0: 0.30000000000000004,
#  687.0: 0.7500000000000001,
#  688.0: 3.149999999999999,
#  689.0: 0.15000000000000002,
#  690.0: 0.30000000000000004,
#  691.0: 0.45000000000000007,
#  692.0: 3.299999999999999,
#  693.0: 0.7500000000000001,
#  694.0: 0.15000000000000002,
#  695.0: 0.6000000000000001,
#  696.0: 7.050000000000006,
#  697.0: 0.45000000000000007,
#  698.0: 3.8999999999999986,
#  699.0: 0.7500000000000001,
#  700.0: 1.65,
#  701.0: 0.15000000000000002,
#  702.0: 0.30000000000000004,
#  703.0: 0.9000000000000001,
#  704.0: 3.8999999999999986,
#  705.0: 1.7999999999999998,
#  706.0: 6.450000000000005,
#  707.0: 0.30000000000000004,
#  708.0: 12.000000000000018,
#  709.0: 4.35,
#  710.0: 0.15000000000000002,
#  711.0: 0.45000000000000007,
#  712.0: 0.30000000000000004,
#  713.0: 8.55000000000001,
#  714.0: 1.7999999999999998,
#  715.0: 41.84999999999978,
#  716.0: 0.15000000000000002,
#  717.0: 9.600000000000012,
#  718.0: 8.70000000000001,
#  719.0: 7.500000000000007,
#  720.0: 5.250000000000002,
#  721.0: 1.7999999999999998,
#  722.0: 5.250000000000002,
#  723.0: 1.7999999999999998,
#  724.0: 0.15000000000000002,
#  725.0: 0.30000000000000004,
#  726.0: 3.5999999999999988,
#  727.0: 0.30000000000000004,
#  728.0: 9.750000000000012,
#  729.0: 2.3999999999999995,
#  730.0: 0.7500000000000001,
#  731.0: 5.100000000000001,
#  732.0: 7.6500000000000075,
#  733.0: 4.35,
#  734.0: 0.45000000000000007,
#  735.0: 1.7999999999999998,
#  736.0: 0.7500000000000001,
#  737.0: 19.349999999999994,
#  738.0: 11.100000000000016,
#  739.0: 0.30000000000000004,
#  740.0: 3.8999999999999986,
#  741.0: 0.15000000000000002,
#  742.0: 8.40000000000001,
#  743.0: 2.2499999999999996,
#  744.0: 0.15000000000000002,
#  745.0: 3.449999999999999,
#  746.0: 4.950000000000001,
#  747.0: 1.35,
#  748.0: 6.0000000000000036,
#  749.0: 0.15000000000000002,
#  750.0: 2.999999999999999,
#  751.0: 4.199999999999999,
#  752.0: 0.6000000000000001,
#  753.0: 20.69999999999998,
#  754.0: 0.15000000000000002,
#  755.0: 1.0500000000000003,
#  756.0: 22.499999999999964,
#  757.0: 0.15000000000000002,
#  758.0: 1.35,
#  759.0: 0.45000000000000007,
#  760.0: 8.85000000000001,
#  761.0: 0.45000000000000007,
#  762.0: 5.400000000000002,
#  763.0: 9.750000000000012,
#  764.0: 0.30000000000000004,
#  765.0: 17.400000000000013,
#  766.0: 2.0999999999999996,
#  767.0: 0.15000000000000002,
#  768.0: 0.6000000000000001,
#  769.0: 24.89999999999994,
#  770.0: 2.2499999999999996,
#  771.0: 0.6000000000000001,
#  772.0: 21.599999999999973,
#  773.0: 6.450000000000005,
#  774.0: 0.9000000000000001,
#  775.0: 14.700000000000024,
#  776.0: 9.300000000000011,
#  777.0: 0.15000000000000002,
#  778.0: 1.5,
#  779.0: 0.7500000000000001,
#  780.0: 7.950000000000008,
#  781.0: 2.5499999999999994,
#  782.0: 10.500000000000014,
#  783.0: 11.700000000000017,
#  784.0: 2.2499999999999996,
#  785.0: 9.00000000000001,
#  786.0: 10.950000000000015,
#  787.0: 0.15000000000000002,
#  788.0: 12.75000000000002,
#  789.0: 1.0500000000000003,
#  790.0: 0.30000000000000004,
#  791.0: 6.750000000000005,
#  792.0: 0.15000000000000002,
#  793.0: 0.30000000000000004,
#  794.0: 0.15000000000000002,
#  795.0: 0.15000000000000002,
#  796.0: 6.150000000000004,
#  797.0: 0.6000000000000001,
#  798.0: 11.250000000000016,
#  799.0: 0.9000000000000001,
#  800.0: 4.35,
#  801.0: 1.0500000000000003,
#  802.0: 0.30000000000000004,
#  803.0: 31.199999999999882,
#  804.0: 0.6000000000000001,
#  805.0: 0.7500000000000001,
#  806.0: 0.15000000000000002,
#  807.0: 2.3999999999999995,
#  808.0: 0.15000000000000002,
#  809.0: 2.849999999999999,
#  810.0: 0.15000000000000002,
#  811.0: 0.15000000000000002,
#  812.0: 3.449999999999999,
#  813.0: 0.6000000000000001,
#  814.0: 0.15000000000000002,
#  815.0: 0.45000000000000007,
#  816.0: 2.3999999999999995,
#  817.0: 0.45000000000000007,
#  818.0: 0.6000000000000001,
#  819.0: 0.9000000000000001,
#  820.0: 13.950000000000022,
#  821.0: 3.449999999999999,
#  822.0: 0.30000000000000004,
#  823.0: 2.999999999999999,
#  824.0: 37.64999999999982,
#  825.0: 0.45000000000000007,
#  826.0: 0.30000000000000004,
#  827.0: 4.5,
#  828.0: 0.15000000000000002,
#  829.0: 58.49999999999962,
#  830.0: 6.0000000000000036,
#  831.0: 1.2000000000000002,
#  832.0: 0.7500000000000001,
#  833.0: 1.7999999999999998,
#  834.0: 0.15000000000000002,
#  835.0: 3.8999999999999986,
#  836.0: 3.7499999999999987,
#  837.0: 0.7500000000000001,
#  838.0: 1.2000000000000002,
#  839.0: 0.7500000000000001,
#  840.0: 1.7999999999999998,
#  841.0: 0.15000000000000002,
#  842.0: 0.15000000000000002,
#  843.0: 8.55000000000001,
#  844.0: 0.15000000000000002,
#  845.0: 0.7500000000000001,
#  846.0: 0.6000000000000001,
#  847.0: 4.199999999999999,
#  848.0: 0.7500000000000001,
#  849.0: 0.30000000000000004,
#  850.0: 67.04999999999968,
#  851.0: 13.800000000000022,
#  852.0: 13.800000000000022,
#  853.0: 0.30000000000000004,
#  854.0: 3.449999999999999,
#  855.0: 0.6000000000000001,
#  856.0: 0.30000000000000004,
#  857.0: 0.15000000000000002,
#  858.0: 0.15000000000000002,
#  859.0: 9.450000000000012,
#  860.0: 1.5,
#  861.0: 0.15000000000000002,
#  862.0: 2.3999999999999995,
#  863.0: 0.15000000000000002,
#  864.0: 9.600000000000012,
#  865.0: 0.15000000000000002,
#  866.0: 7.800000000000008,
#  867.0: 8.250000000000009,
#  868.0: 4.65,
#  869.0: 0.15000000000000002,
#  870.0: 0.15000000000000002,
#  871.0: 10.050000000000013,
#  872.0: 20.84999999999998,
#  873.0: 2.999999999999999,
#  874.0: 1.9499999999999997,
#  875.0: 1.0500000000000003,
#  876.0: 17.250000000000014,
#  877.0: 0.6000000000000001,
#  878.0: 0.15000000000000002,
#  879.0: 11.700000000000017,
#  880.0: 71.99999999999987,
#  881.0: 2.5499999999999994,
#  882.0: 0.7500000000000001,
#  883.0: 0.45000000000000007,
#  884.0: 1.35,
#  885.0: 16.350000000000023,
#  886.0: 1.35,
#  887.0: 0.15000000000000002,
#  888.0: 2.5499999999999994,
#  889.0: 0.6000000000000001,
#  890.0: 2.849999999999999,
#  891.0: 3.5999999999999988,
#  892.0: 0.6000000000000001,
#  893.0: 0.6000000000000001,
#  894.0: 1.0500000000000003,
#  895.0: 25.04999999999994,
#  896.0: 7.6500000000000075,
#  897.0: 6.150000000000004,
#  898.0: 3.8999999999999986,
#  899.0: 16.65000000000002,
#  900.0: 0.15000000000000002,
#  901.0: 0.6000000000000001,
#  902.0: 0.45000000000000007,
#  903.0: 0.6000000000000001,
#  904.0: 13.650000000000022,
#  905.0: 0.15000000000000002,
#  906.0: 0.9000000000000001,
#  907.0: 0.45000000000000007,
#  908.0: 11.250000000000016,
#  909.0: 0.7500000000000001,
#  910.0: 0.15000000000000002,
#  911.0: 0.45000000000000007,
#  912.0: 0.15000000000000002,
#  913.0: 6.600000000000005,
#  914.0: 0.9000000000000001,
#  915.0: 0.30000000000000004,
#  916.0: 0.6000000000000001,
#  917.0: 0.6000000000000001,
#  918.0: 0.30000000000000004,
#  919.0: 10.500000000000014,
#  920.0: 12.000000000000018,
#  921.0: 2.849999999999999,
#  922.0: 1.7999999999999998,
#  923.0: 0.15000000000000002,
#  924.0: 0.7500000000000001,
#  925.0: 1.7999999999999998,
#  926.0: 10.650000000000015,
#  927.0: 0.30000000000000004,
#  928.0: 0.6000000000000001,
#  929.0: 0.15000000000000002,
#  930.0: 0.15000000000000002,
#  931.0: 0.30000000000000004,
#  932.0: 6.900000000000006,
#  933.0: 0.15000000000000002,
#  934.0: 0.7500000000000001,
#  935.0: 10.350000000000014,
#  936.0: 52.49999999999968,
#  937.0: 0.15000000000000002,
#  938.0: 0.30000000000000004,
#  939.0: 23.99999999999995,
#  940.0: 3.299999999999999,
#  941.0: 0.9000000000000001,
#  942.0: 0.45000000000000007,
#  943.0: 0.15000000000000002,
#  944.0: 0.9000000000000001,
#  945.0: 0.9000000000000001,
#  946.0: 0.15000000000000002,
#  947.0: 0.15000000000000002,
#  948.0: 0.30000000000000004,
#  949.0: 21.449999999999974,
#  950.0: 0.30000000000000004,
#  951.0: 4.65,
#  952.0: 33.29999999999986,
#  953.0: 1.35,
#  954.0: 0.6000000000000001,
#  955.0: 5.850000000000003,
#  956.0: 0.45000000000000007,
#  957.0: 28.34999999999991,
#  958.0: 3.5999999999999988,
#  959.0: 0.15000000000000002,
#  960.0: 88.6500000000005,
#  961.0: 1.5,
#  962.0: 0.45000000000000007,
#  963.0: 22.199999999999967,
#  964.0: 18.450000000000003,
#  965.0: 5.100000000000001,
#  966.0: 1.0500000000000003,
#  967.0: 11.100000000000016,
#  968.0: 6.750000000000005,
#  969.0: 10.800000000000015,
#  970.0: 3.299999999999999,
#  971.0: 0.6000000000000001,
#  972.0: 5.5500000000000025,
#  973.0: 0.45000000000000007,
#  974.0: 0.15000000000000002,
#  975.0: 3.149999999999999,
#  976.0: 3.5999999999999988,
#  977.0: 16.950000000000017,
#  978.0: 18.6,
#  979.0: 0.45000000000000007,
#  980.0: 3.149999999999999,
#  981.0: 1.65,
#  982.0: 29.3999999999999,
#  983.0: 3.8999999999999986,
#  984.0: 5.100000000000001,
#  985.0: 0.15000000000000002,
#  986.0: 1.7999999999999998,
#  987.0: 0.45000000000000007,
#  988.0: 0.15000000000000002,
#  989.0: 0.15000000000000002,
#  990.0: 0.45000000000000007,
#  991.0: 7.350000000000007,
#  992.0: 0.15000000000000002,
#  993.0: 0.15000000000000002,
#  994.0: 3.5999999999999988,
#  995.0: 20.549999999999983,
#  996.0: 0.6000000000000001,
#  997.0: 44.24999999999976,
#  998.0: 65.09999999999961,
#  999.0: 5.400000000000002,
#  1000.0: 0.15000000000000002,
#  ...}

# %%
# Sort nodes by PageRank scores
sorted_nodes = sorted(page_rank_scores.items(), key=lambda item: item[1], reverse=True)

# Calculate the top 30% of nodes
new_top_30_percent_count = int(len(sorted_nodes) * 0.30)
new_top_30_percent_count = sorted_nodes[:new_top_30_percent_count]

# %%
# Output the top 30% of nodes and their PageRank scores
for node, score in top_30_percent_nodes:
    print(f'Node: {node:.0f}, PageRank Score: {score:.2e}')

# %%
top_30_percent_nodes[node]

# %%
type(top_30_percent_nodes)

# %% [markdown]
# ### Incemental code check

# %%
graph_df.head()
# Out:
#    Unnamed: 0  u     i     ts  label  idx
# 0           0  1  8228    0.0    0.0    1
# 1           1  2  8229   36.0    0.0    2
# 2           2  2  8229   77.0    0.0    3
# 3           3  3  8230  131.0    0.0    4
# 4           4  2  8229  150.0    0.0    5

# %%
train_df = graph_df[graph_df['ts']<val_time]
train_df.head()
# Out:
#    Unnamed: 0  u     i     ts  label  idx
# 0           0  1  8228    0.0    0.0    1
# 1           1  2  8229   36.0    0.0    2
# 2           2  2  8229   77.0    0.0    3
# 3           3  3  8230  131.0    0.0    4
# 4           4  2  8229  150.0    0.0    5

# %%
len(train_df)
# Out:
# 1575

# %%
# Set the working directory to the project root
project_root = os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')) # this might cause issue
sys.path.append(project_root)

# %%
from preprocess_data import temporal_pr

# %%
tpr_scores_ts = temporal_pr.calc_inc_timestamp_pagerank(train_df)
# Out:
# /home2/hmnshpl/projects/DyGLib/preprocess_data/temporal_pr.py:250: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['u'] = df['u'].astype(int)
# /home2/hmnshpl/projects/DyGLib/preprocess_data/temporal_pr.py:251: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['i'] = df['i'].astype(int)
# /home2/hmnshpl/projects/DyGLib/preprocess_data/temporal_pr.py:252: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ts'] = pd.to_datetime(df['ts'])
# /home2/hmnshpl/projects/DyGLib/preprocess_data/temporal_pr.py:255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by='ts', inplace=True)
# Calculating PageRank:   0%|          | 0/1543 [00:00<?, ?it/s]
# Calculating PageRank: 100%|██████████| 1543/1543 [54:07<00:00,  2.10s/it]

# %%
len(tpr_scores_ts[0]), len(tpr_scores_ts.keys())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 len(tpr_scores_ts[0]), len(tpr_scores_ts.keys())
#
# KeyError: 0

# %%
list(tpr_scores_ts.keys())[0]
# Out:
# Timestamp('1970-01-01 00:00:00')

# %%
tpr_scores_ts[list(tpr_scores_ts.keys())[3]]
# Out:
# {1.0: 0.0013928926949274005,
#  8228.0: 0.002639169402188598,
#  2.0: 0.0018083182640144667,
#  8229.0: 0.0018083182640144667,
#  3.0: 0.0018083182640144667,
#  8230.0: 0.0018083182640144667,
#  4.0: 0.0018083182640144667,
#  8231.0: 0.0018083182640144667,
#  5.0: 0.0018083182640144667,
#  8232.0: 0.0018083182640144667,
#  6.0: 0.0018083182640144667,
#  8233.0: 0.0018083182640144667,
#  7.0: 0.0018083182640144667,
#  8234.0: 0.0018083182640144667,
#  8.0: 0.0013928926949274005,
#  9.0: 0.0017165374808758454,
#  8235.0: 0.0016840327213946938,
#  10.0: 0.0010269718440878144,
#  8236.0: 0.004445439519215776,
#  11.0: 0.0011445476487514708,
#  8237.0: 0.0020548260593158943,
#  12.0: 0.0018083182640144667,
#  8238.0: 0.0018083182640144667,
#  13.0: 0.0018083182640144667,
#  8239.0: 0.0018083182640144667,
#  14.0: 0.0018083182640144667,
#  8240.0: 0.0018083182640144667,
#  15.0: 0.0011612577928739702,
#  8241.0: 0.0020941397013415504,
#  16.0: 0.0018083182640144667,
#  8242.0: 0.0018083182640144667,
#  17.0: 0.0016267359877439034,
#  8243.0: 0.002466762403230509,
#  18.0: 0.007714786011269104,
#  8244.0: 0.0018122371550727376,
#  19.0: 0.0009522462322616954,
#  8245.0: 0.004005878638349049,
#  20.0: 0.0018711294443987466,
#  8246.0: 0.002858026330960055,
#  21.0: 0.0013928926949274005,
#  8247.0: 0.002639169402188598,
#  22.0: 0.0010917475354503968,
#  8248.0: 0.0028958850997053134,
#  23.0: 0.0047965421333625346,
#  8249.0: 0.0009507590961576005,
#  8250.0: 0.0046346436646249305,
#  24.0: 0.0018083182640144667,
#  8251.0: 0.0018083182640144667,
#  25.0: 0.0013928926949274005,
#  8252.0: 0.002639169402188598,
#  26.0: 0.0013928926949274005,
#  8253.0: 0.002639169402188598,
#  27.0: 0.0018083182640144667,
#  8254.0: 0.0018083182640144667,
#  28.0: 0.0018083182640144667,
#  8255.0: 0.0018083182640144667,
#  29.0: 0.0018083182640144667,
#  8256.0: 0.0018083182640144667,
#  30.0: 0.0013928926949274005,
#  8257.0: 0.002639169402188598,
#  31.0: 0.0018083182640144667,
#  8258.0: 0.0018083182640144667,
#  32.0: 0.0018083182640144667,
#  8259.0: 0.0018083182640144667,
#  33.0: 0.0013928926949274005,
#  8260.0: 0.002639169402188598,
#  34.0: 0.0010613573575337584,
#  8261.0: 0.00557725876812199,
#  35.0: 0.0010053994414080925,
#  8262.0: 0.009500808922459884,
#  36.0: 0.0013928926949274005,
#  8263.0: 0.002639169402188598,
#  37.0: 0.0020617614183821914,
#  8264.0: 0.001147497508474479,
#  38.0: 0.0013928926949274005,
#  8265.0: 0.002639169402188598,
#  39.0: 0.0010613573575337584,
#  40.0: 0.003470020540362731,
#  8266.0: 0.0012544175052317122,
#  41.0: 0.006174803355454222,
#  42.0: 0.0010450608296387709,
#  8267.0: 0.0027311082693594617,
#  43.0: 0.0018083182640144667,
#  8268.0: 0.0018083182640144667,
#  44.0: 0.0013928926949274005,
#  8269.0: 0.002639169402188598,
#  45.0: 0.0018083182640144667,
#  8270.0: 0.0018083182640144667,
#  46.0: 0.0009278211577034303,
#  47.0: 0.0018083182640144667,
#  8271.0: 0.0018083182640144667,
#  48.0: 0.0018083182640144667,
#  8272.0: 0.0018083182640144667,
#  243.0: 0.001980245091750478,
#  8412.0: 0.002103191895463039,
#  244.0: 0.0013928926949274005,
#  245.0: 0.0013928926949274005,
#  246.0: 0.0013928926949274005,
#  8413.0: 0.002639169402188598,
#  247.0: 0.0010917475354503968,
#  248.0: 0.0018083182640144667,
#  8414.0: 0.0018083182640144667,
#  8415.0: 0.0009273213803776259,
#  249.0: 0.0018083182640144667,
#  8416.0: 0.0018083182640144667,
#  250.0: 0.0013928926949274005,
#  251.0: 0.0018083182640144667,
#  8417.0: 0.0018083182640144667,
#  252.0: 0.0011282559738659305,
#  253.0: 0.0018083182640144667,
#  8418.0: 0.0018083182640144667,
#  254.0: 0.0018083182640144667,
#  8419.0: 0.0018083182640144667,
#  255.0: 0.002347641255036325,
#  8420.0: 0.0012689952729926079,
#  256.0: 0.0010269718440878144,
#  8421.0: 0.0009537327994866402,
#  257.0: 0.0018083182640144667,
#  8422.0: 0.0018083182640144667,
#  258.0: 0.0018083182640144667,
#  8423.0: 0.0018083182640144667,
#  259.0: 0.0013928926949274005,
#  8424.0: 0.002639169402188598,
#  260.0: 0.0018083182640144667,
#  8425.0: 0.0018083182640144667,
#  261.0: 0.0012544175052317122,
#  8426.0: 0.0012544175052317122,
#  8427.0: 0.0009273213803776259,
#  8428.0: 0.00267866770720966,
#  262.0: 0.0013928926949274005,
#  8429.0: 0.0018540797967309041,
#  263.0: 0.001046704720688179,
#  264.0: 0.0013928926949274005,
#  265.0: 0.0018083182640144667,
#  8430.0: 0.0018083182640144667,
#  8431.0: 0.0011384438526173498,
#  266.0: 0.0010450608296387709,
#  267.0: 0.00118723305523272,
#  268.0: 0.0013928926949274005,
#  269.0: 0.0018083182640144667,
#  8432.0: 0.0018083182640144667,
#  270.0: 0.0012544175052317122,
#  271.0: 0.0018083182640144667,
#  8433.0: 0.0018083182640144667,
#  272.0: 0.0010162045866047079,
#  273.0: 0.0013928926949274005,
#  8434.0: 0.0018552857013936818,
#  274.0: 0.0010592310297306727,
#  275.0: 0.0013928926949274005,
#  8435.0: 0.0009545030278279273,
#  276.0: 0.0018083182640144667,
#  8436.0: 0.0018083182640144667,
#  277.0: 0.0010597432352129454,
#  278.0: 0.0010162045866047079,
#  279.0: 0.002347641255036325,
#  8437.0: 0.0012689952729926079,
#  8438.0: 0.002347641255036325,
#  280.0: 0.0012544175052317122,
#  281.0: 0.0010302028208936395,
#  8439.0: 0.0009270057268279682,
#  282.0: 0.0011147313093075087,
#  283.0: 0.0013928926949274005,
#  8440.0: 0.0013928926949274005,
#  284.0: 0.0018083182640144667,
#  8441.0: 0.0018083182640144667,
#  285.0: 0.0018086202425077712,
#  286.0: 0.0012689952729926079,
#  287.0: 0.0010270612582480281,
#  288.0: 0.0012544175052317122,
#  289.0: 0.0018083182640144667,
#  8442.0: 0.0018083182640144667,
#  290.0: 0.0013928926949274005,
#  8443.0: 0.002639169402188598,
#  291.0: 0.0018083182640144667,
#  8444.0: 0.0018083182640144667,
#  292.0: 0.0013928926949274005,
#  293.0: 0.0012544175052317122,
#  294.0: 0.0018083182640144667,
#  8445.0: 0.0018083182640144667,
#  295.0: 0.0018083182640144667,
#  8446.0: 0.0018083182640144667,
#  296.0: 0.0011851799103838679,
#  8447.0: 0.0009270057268279682,
#  297.0: 0.001046704720688179,
#  298.0: 0.001033088353503524,
#  299.0: 0.0010961601455794963,
#  300.0: 0.0012689952729926079,
#  301.0: 0.001046704720688179,
#  302.0: 0.0018083182640144667,
#  8448.0: 0.0018083182640144667,
#  303.0: 0.0018083182640144667,
#  8449.0: 0.0018083182640144667,
#  304.0: 0.001965716197527834,
#  305.0: 0.0018083182640144667,
#  8450.0: 0.0018083182640144667,
#  306.0: 0.0013928926949274005,
#  8451.0: 0.001106677735491462,
#  307.0: 0.0010592310297306727,
#  308.0: 0.0013928926949274005,
#  309.0: 0.002639169402188598,
#  8452.0: 0.0013928926949274005,
#  310.0: 0.0018083182640144667,
#  8453.0: 0.0018083182640144667,
#  311.0: 0.0009522462322616954,
#  312.0: 0.0013928926949274005,
#  313.0: 0.0018083182640144667,
#  8454.0: 0.0018083182640144667,
#  314.0: 0.0011612577928739702,
#  8455.0: 0.0020941397013415504,
#  8456.0: 0.0013928926949274005,
#  315.0: 0.000992933091816873,
#  316.0: 0.0010302028208936395,
#  317.0: 0.00118723305523272,
#  318.0: 0.000992933091816873,
#  319.0: 0.001046704720688179,
#  320.0: 0.0010863897022387512,
#  321.0: 0.0011851799103838679,
#  322.0: 0.000992933091816873,
#  323.0: 0.0013928926949274005,
#  324.0: 0.0011651031291138973}

# %%
len(train_df)
len(train_df['u'].unique()), len(train_df['i'].unique()), len(train_df['ts'].unique()), len(train_df['u'].unique()) + len(train_df['i'].unique())
# Out:
# (324, 229, 1543, 553)

# %%
_df = pd.DataFrame.from_dict(tpr_scores_ts, orient='index')

# %%
_df.index[0].astype(str)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 _df.index[0].astype(str)
#
# AttributeError: 'Timestamp' object has no attribute 'astype'

# %%
_df.index = _df.index.astype(str)
_df.head()
# Out:
#                                  1.0       8228.0    2.0       8229.0  \
# 1970-01-01 00:00:00.000000000  0.001393  0.002639  0.001808  0.001808
# 1970-01-01 00:00:00.000000036  0.001393  0.002639  0.001808  0.001808
# 1970-01-01 00:00:00.000000077  0.001393  0.002639  0.001808  0.001808
# 1970-01-01 00:00:00.000000131  0.001393  0.002639  0.001808  0.001808
# 1970-01-01 00:00:00.000000150  0.001393  0.002639  0.001808  0.001808
#
#                                  3.0       8230.0    4.0       8231.0  \
# 1970-01-01 00:00:00.000000000  0.001808  0.001808  0.001808  0.001808
# 1970-01-01 00:00:00.000000036  0.001808  0.001808  0.001808  0.001808
# 1970-01-01 00:00:00.000000077  0.001808  0.001808  0.001808  0.001808
# 1970-01-01 00:00:00.000000131  0.001808  0.001808  0.001808  0.001808
# 1970-01-01 00:00:00.000000150  0.001808  0.001808  0.001808  0.001808
#
#                                  5.0       8232.0  ...    315.0    316.0   \
# 1970-01-01 00:00:00.000000000  0.001808  0.001808  ...  0.000993  0.00103
# 1970-01-01 00:00:00.000000036  0.001808  0.001808  ...  0.000993  0.00103
# 1970-01-01 00:00:00.000000077  0.001808  0.001808  ...  0.000993  0.00103
# 1970-01-01 00:00:00.000000131  0.001808  0.001808  ...  0.000993  0.00103
# 1970-01-01 00:00:00.000000150  0.001808  0.001808  ...  0.000993  0.00103
#
#                                  317.0     318.0     319.0     320.0   \
# 1970-01-01 00:00:00.000000000  0.001187  0.000993  0.001047  0.001086
# 1970-01-01 00:00:00.000000036  0.001187  0.000993  0.001047  0.001086
# 1970-01-01 00:00:00.000000077  0.001187  0.000993  0.001047  0.001086
# 1970-01-01 00:00:00.000000131  0.001187  0.000993  0.001047  0.001086
# 1970-01-01 00:00:00.000000150  0.001187  0.000993  0.001047  0.001086
#
#                                  321.0     322.0     323.0     324.0
# 1970-01-01 00:00:00.000000000  0.001185  0.000993  0.001393  0.001165
# 1970-01-01 00:00:00.000000036  0.001185  0.000993  0.001393  0.001165
# 1970-01-01 00:00:00.000000077  0.001185  0.000993  0.001393  0.001165
# 1970-01-01 00:00:00.000000131  0.001185  0.000993  0.001393  0.001165
# 1970-01-01 00:00:00.000000150  0.001185  0.000993  0.001393  0.001165
#
# [5 rows x 553 columns]

# %%
tpr_scores_ts_ = temporal_pr.temporal_page_rank(temporal_pr.build_graph(train_df))
tpr_scores_ts = temporal_pr.optimized_temporal_page_rank(temporal_pr.build_graph(train_df))

# %%
tpr_scores_ts
# Out:
# array([2.89164558e+05, 3.40193598e+05, 1.80831826e-03, 1.80831826e-03,
#        1.80831826e-03, 1.80831826e-03, 1.80831826e-03, 1.80831826e-03,
#        1.80831826e-03, 1.80831826e-03, 1.80831826e-03, 1.80831826e-03,
#        1.80831826e-03, 1.80831826e-03, 2.89164558e+05, 1.35716594e+44,
#        4.42422552e+44, 2.61121150e+44, 9.40482626e+44, 1.51714041e+22,
#        2.85452139e+22, 1.80831826e-03, 1.80831826e-03, 1.80831826e-03,
#        1.80831826e-03, 1.80831826e-03, 1.80831826e-03, 6.64022808e+22,
#        1.82040442e+23, 1.80831826e-03, 1.80831826e-03, 1.66671611e+46,
#        1.42655983e+46, 9.37637429e+46, 2.73498882e+46, 2.71017994e+45,
#        9.74975643e+45, 2.46106556e+30, 8.33541910e+29, 2.89164558e+05,
#        3.40193598e+05, 1.79164525e+44, 6.44490099e+44, 3.22396556e+46,
#        8.69854664e+45, 4.56874339e+46, 1.80831826e-03, 1.80831826e-03,
#        2.89164558e+05, 3.40193598e+05, 2.89164558e+05, 3.40193598e+05,
#        1.80831826e-03, 1.80831826e-03, 1.80831826e-03, 1.80831826e-03,
#        1.80831826e-03, 1.80831826e-03, 2.89164558e+05, 3.40193598e+05,
#        1.80831826e-03, 1.80831826e-03, 1.80831826e-03, 1.80831826e-03,
#        2.89164558e+05, 3.40193598e+05, 1.86536170e+30, 2.61011766e+30,
#        1.55140595e+43, 3.61445879e+43, 2.89164558e+05, 3.40193598e+05,
#        4.89465954e+23, 1.72221903e+23, 2.89164558e+05, 3.40193598e+05,
#        1.86536170e+30, 1.65356857e+14, 1.40553328e+14, 7.20150483e+45,
#        1.32736059e+44, 4.77647976e+44, 1.80831826e-03, 1.80831826e-03,
#        2.89164558e+05, 3.40193598e+05, 1.80831826e-03, 1.80831826e-03,
#        1.27012563e+46, 1.80831826e-03, 1.80831826e-03, 1.80831826e-03,
#        1.80831826e-03, 1.80831826e-03, 1.80831826e-03,
#        2.89164558e+05, 2.91506425e+24, 6.64240253e+24, 2.89164558e+05,
#        3.40193598e+05, 1.49164307e+44, 5.29161556e+23, 2.37184497e+23,
#        2.89164558e+05, 2.89164558e+05, 2.89164558e+05, 3.40193598e+05,
#        1.79164525e+44, 1.80831826e-03, 1.80831826e-03, 1.94435788e+45,
#        1.80831826e-03, 1.80831826e-03, 2.89164558e+05, 1.80831826e-03,
#        1.80831826e-03, 8.95148186e+44, 1.80831826e-03, 1.80831826e-03,
#        1.80831826e-03, 1.80831826e-03, 2.05324623e+11, 1.26897596e+11,
#        2.61121150e+44, 6.57788604e+44, 1.80831826e-03, 1.80831826e-03,
#        1.80831826e-03, 1.80831826e-03, 2.89164558e+05, 3.40193598e+05,
#        1.80831826e-03, 1.80831826e-03, 1.40553328e+14, 1.40553328e+14,
#        1.94435788e+45, 2.28772608e+45, 2.89164558e+05, 7.11228430e+44,
#        1.49164307e+44, 2.89164558e+05, 1.80831826e-03, 1.80831826e-03,
#        6.01595464e+18, 1.32736059e+44, 7.64078993e+16, 2.89164558e+05,
#        1.80831826e-03, 1.80831826e-03, 1.40553328e+14, 1.80831826e-03,
#        1.80831826e-03, 1.00477439e+46, 2.89164558e+05, 4.38878745e+44,
#        1.97486097e+44, 2.89164558e+05, 4.05931493e+44, 1.80831826e-03,
#        1.80831826e-03, 1.21963151e+44, 1.00477439e+46, 2.05324623e+11,
#        1.26897596e+11, 2.05324623e+11, 1.40553328e+14, 6.35788449e+44,
#        2.52984156e+46, 2.14556054e+22, 2.89164558e+05, 2.89164558e+05,
#        1.80831826e-03, 1.80831826e-03, 2.03016026e+45, 1.26897596e+11,
#        1.83518406e+45, 1.40553328e+14, 1.80831826e-03, 1.80831826e-03,
#        2.89164558e+05, 3.40193598e+05, 1.80831826e-03, 1.80831826e-03,
#        2.89164558e+05, 1.40553328e+14, 1.80831826e-03, 1.80831826e-03,
#        1.80831826e-03, 1.80831826e-03, 2.29966359e+20, 2.52984156e+46,
#        1.49164307e+44, 3.12041325e+45, 3.03948507e+32, 1.26897596e+11,
#        1.49164307e+44, 1.80831826e-03, 1.80831826e-03, 1.80831826e-03,
#        1.80831826e-03, 2.34086392e+44, 1.80831826e-03, 1.80831826e-03,
#        2.89164558e+05, 6.33505933e+43, 1.97486097e+44, 2.89164558e+05,
#        3.40193598e+05, 2.89164558e+05, 1.80831826e-03, 1.80831826e-03,
#        2.71017994e+45, 2.89164558e+05, 1.80831826e-03, 1.80831826e-03,
#        6.64022808e+22, 1.82040442e+23, 2.89164558e+05, 1.01436679e+46,
#        6.35788449e+44, 7.64078993e+16, 1.01436679e+46, 1.49164307e+44,
#        3.84229204e+23, 2.29966359e+20, 1.01436679e+46, 2.89164558e+05,
#        1.44932352e+23])

# %%
len(tpr_scores_ts)
# Out:
# 553

# %%
tpr_df = pd.DataFrame.from_dict(tpr_scores_ts_, orient='index')

# %%
tpr_df.sort_index().to_csv('./TPR_basic.csv')

# %%
edges = train_df[['u', 'i', 'ts']].values

# %%
type(edges)

# %%
np.unique(edges[:, 2])

# %%
np.random.choice(train_df['ts'])

# %%
_ts =  np.random.choice(train_df['ts']) # 1835832.0

# %%
edges_up_to_ts = edges[edges[:, 2] <= _ts]
